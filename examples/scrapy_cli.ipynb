# %% [markdown]
# # Scrapy CLI Usage
#
# Contains some helpful examples of scrapy cli usage pertaining to this project

# %% [markdown]
# **List available spiders**

# %%
# !scrapy list
# Out:
# businessstandard
# businesstoday
# cnbctv18
# economictimes
# financialexpress
# firstpost
# freepressjournal
# indianexpress
# ipfy
# moneycontrol
# ndtvprofit
# news18
# outlookindia
# thehindu
# thehindubusinessline
# zeenews

# %% [markdown]
# **Scraping benchmarks**

# %%
# !scrapy bench
# Out:
# 2024-09-13 11:59:03 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: news_scraper)
# 2024-09-13 11:59:03 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.10.7 (main, Sep  5 2022, 13:12:31) [GCC 11.2.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.1, Platform Linux-6.8.0-40-generic-x86_64-with-glibc2.35
# 2024-09-13 11:59:04 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-09-13 11:59:04 [scrapy.extensions.telnet] INFO: Telnet Password: 60e8890da33f6398
# 2024-09-13 11:59:04 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.closespider.CloseSpider',
#  'scrapy.extensions.logstats.LogStats']
# 2024-09-13 11:59:04 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'news_scraper',
#  'CLOSESPIDER_TIMEOUT': 10,
#  'CONCURRENT_ITEMS': 1200,
#  'CONCURRENT_REQUESTS': 320,
#  'COOKIES_ENABLED': False,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'HTTPCACHE_ENABLED': True,
#  'HTTPCACHE_IGNORE_HTTP_CODES': [403],
#  'LOGSTATS_INTERVAL': 1,
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'news_scraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'RETRY_HTTP_CODES': [500, 502, 503, 504, 522, 524, 408, 403, 429],
#  'SPIDER_MODULES': ['news_scraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Googlebot-News/2.1 (+http://www.google.com/bot.html)'}
# 2024-09-13 11:59:04 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'news_scraper.middlewares.NewsScraperDownloaderMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats',
#  'scrapy.downloadermiddlewares.httpcache.HttpCacheMiddleware']
# 2024-09-13 11:59:04 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-09-13 11:59:04 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-09-13 11:59:04 [scrapy.core.engine] INFO: Spider opened
# 2024-09-13 11:59:04 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:04 [follow] INFO: Spider opened: follow
# 2024-09-13 11:59:04 [follow] INFO: Floating IPs (total: 0): []
# 2024-09-13 11:59:04 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-09-13 11:59:06 [scrapy.extensions.logstats] INFO: Crawled 350 pages (at 21000 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:06 [scrapy.extensions.logstats] INFO: Crawled 390 pages (at 2400 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:14 [scrapy.extensions.logstats] INFO: Crawled 398 pages (at 480 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:17 [scrapy.core.engine] INFO: Closing spider (closespider_timeout)
# 2024-09-13 11:59:18 [scrapy.extensions.logstats] INFO: Crawled 398 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:20 [scrapy.extensions.logstats] INFO: Crawled 406 pages (at 480 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:21 [scrapy.extensions.logstats] INFO: Crawled 414 pages (at 480 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:22 [scrapy.extensions.logstats] INFO: Crawled 430 pages (at 960 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:23 [scrapy.extensions.logstats] INFO: Crawled 446 pages (at 960 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:24 [scrapy.extensions.logstats] INFO: Crawled 470 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:25 [scrapy.extensions.logstats] INFO: Crawled 486 pages (at 960 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:26 [scrapy.extensions.logstats] INFO: Crawled 510 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:27 [scrapy.extensions.logstats] INFO: Crawled 534 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:28 [scrapy.extensions.logstats] INFO: Crawled 550 pages (at 960 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:29 [scrapy.extensions.logstats] INFO: Crawled 574 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:30 [scrapy.extensions.logstats] INFO: Crawled 590 pages (at 960 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:31 [scrapy.extensions.logstats] INFO: Crawled 614 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:32 [scrapy.extensions.logstats] INFO: Crawled 638 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:33 [scrapy.extensions.logstats] INFO: Crawled 654 pages (at 960 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:34 [scrapy.extensions.logstats] INFO: Crawled 678 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:35 [scrapy.extensions.logstats] INFO: Crawled 694 pages (at 960 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:36 [scrapy.extensions.logstats] INFO: Crawled 718 pages (at 1440 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:37 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245074,
#  'downloader/request_count': 718,
#  'downloader/request_method_count/GET': 718,
#  'downloader/response_bytes': 1319004,
#  'downloader/response_count': 718,
#  'downloader/response_status_count/200': 718,
#  'elapsed_time_seconds': 32.736905,
#  'finish_reason': 'closespider_timeout',
#  'finish_time': datetime.datetime(2024, 9, 13, 11, 59, 37, 171652, tzinfo=datetime.timezone.utc),
#  'httpcache/firsthand': 328,
#  'httpcache/hit': 390,
#  'httpcache/miss': 328,
#  'httpcache/store': 328,
#  'log_count/INFO': 33,
#  'memusage/max': 151777280,
#  'memusage/startup': 151777280,
#  'request_depth_max': 4,
#  'response_received_count': 718,
#  'scheduler/dequeued': 718,
#  'scheduler/dequeued/memory': 718,
#  'scheduler/enqueued': 14360,
#  'scheduler/enqueued/memory': 14360,
#  'start_time': datetime.datetime(2024, 9, 13, 11, 59, 4, 434747, tzinfo=datetime.timezone.utc)}
# 2024-09-13 11:59:37 [scrapy.core.engine] INFO: Spider closed (closespider_timeout)

# %% [markdown]
# **Parse an article**

# %%
# !scrapy parse https://www.businesstoday.in/markets/stocks/story/upward-revision-in-eps-estimates-what-analysts-say-on-tcs-q1-results-stock-trading-strategy-436794-2024-07-11
# Out:
# 2024-09-13 11:59:38 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: news_scraper)
# 2024-09-13 11:59:38 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.10.7 (main, Sep  5 2022, 13:12:31) [GCC 11.2.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.1, Platform Linux-6.8.0-40-generic-x86_64-with-glibc2.35
# 2024-09-13 11:59:38 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-09-13 11:59:38 [asyncio] DEBUG: Using selector: EpollSelector
# 2024-09-13 11:59:38 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-09-13 11:59:38 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-09-13 11:59:38 [scrapy.extensions.telnet] INFO: Telnet Password: a26d122e14ca6498
# 2024-09-13 11:59:38 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-09-13 11:59:38 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'news_scraper',
#  'CONCURRENT_ITEMS': 1200,
#  'CONCURRENT_REQUESTS': 320,
#  'COOKIES_ENABLED': False,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'HTTPCACHE_ENABLED': True,
#  'HTTPCACHE_IGNORE_HTTP_CODES': [403],
#  'NEWSPIDER_MODULE': 'news_scraper.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'RETRY_HTTP_CODES': [500, 502, 503, 504, 522, 524, 408, 403, 429],
#  'SPIDER_MODULES': ['news_scraper.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Googlebot-News/2.1 (+http://www.google.com/bot.html)'}
# 2024-09-13 11:59:38 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'news_scraper.middlewares.NewsScraperDownloaderMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats',
#  'scrapy.downloadermiddlewares.httpcache.HttpCacheMiddleware']
# 2024-09-13 11:59:38 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-09-13 11:59:38 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-09-13 11:59:38 [scrapy.core.engine] INFO: Spider opened
# 2024-09-13 11:59:38 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-09-13 11:59:38 [businesstoday] INFO: Spider opened: businesstoday
# 2024-09-13 11:59:38 [businesstoday] INFO: Floating IPs (total: 0): []
# 2024-09-13 11:59:38 [businesstoday] INFO: Already scraped 0 URLs in: data/outputs/businesstoday.jl
# 2024-09-13 11:59:38 [scrapy.extensions.httpcache] DEBUG: Using filesystem cache storage in data/httpcache
# 2024-09-13 11:59:38 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-09-13 11:59:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.businesstoday.in/markets/stocks/story/upward-revision-in-eps-estimates-what-analysts-say-on-tcs-q1-results-stock-trading-strategy-436794-2024-07-11> (referer: None) ['cached']
# 2024-09-13 11:59:38 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-09-13 11:59:38 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 368,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 78711,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.131644,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 9, 13, 11, 59, 38, 592318, tzinfo=datetime.timezone.utc),
#  'httpcache/hit': 1,
#  'httpcompression/response_bytes': 363029,
#  'httpcompression/response_count': 1,
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 13,
#  'memusage/max': 151097344,
#  'memusage/startup': 151097344,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2024, 9, 13, 11, 59, 38, 460674, tzinfo=datetime.timezone.utc)}
# 2024-09-13 11:59:38 [scrapy.core.engine] INFO: Spider closed (finished)
#
# >>> STATUS DEPTH LEVEL 1 <<<
# # Scraped Items  ------------------------------------------------------------
# [{'article_text': 'Tata Consultancy Services Ltd ( ) reported June quarter '
#                   'results that managed to beat analyst estimates, albiet '
#                   'marginally. A couple of analysts are positive on the stock '
#                   'post the Q1 results. Manish Chowdhury, Head of Research at '
#                   'StoxBox said TCS’ Q1FY25 results were a mild surprise on '
#                   'the upside as sequential constant currency (CC) revenue '
#                   'growth of 2.2 per cent reflected an improving business '
#                   'environment in the US. Large deals made in the last year '
#                   'seem to be getting converted into revenue along with the '
#                   'ramp-up of the BSNL deal, he said adding that that the '
#                   'lowering attrition and the net headcount addition is a '
#                   'major positive and augurs well for the company’s '
#                   'utilization levels and subsequently its EBIT margin. '
#                   '"Despite wage hikes in the quarter TCS managed to report a '
#                   'beat on EBIT margin estimates. These positives are bound to '
#                   'lead to an upward revision in EPS estimates but not so much '
#                   'on the revenue side. Key monitorables going forward are 1) '
#                   'updates on the BSNL deal ramp-up; 2) medium-term industry '
#                   'demand trends and impact of macro headwinds on demand; 3) '
#                   'deal wins and deal pipeline; 4) revenue growth and margin '
#                   'outlook for FY25; 5) investments in GenAI partnerships," '
#                   'Chowdhury said. Prashanth Tapse, Senior VP (Research) at '
#                   'Mehta Equities said the profit stood at Rs 12,040 crore '
#                   'against a Bloomberg consensus of Rs 11,959 crore. Revenue '
#                   'at Rs 62,610 crore  was also higher against an estimate of '
#                   'Rs 62,128 crore. All major markets and verticals have '
#                   'returned with sequential growth. Overall the frontline '
#                   'numbers look like the worst is behind us and we may see '
#                   'revival in the IT sector from Q1 earnings, Tapse said. '
#                   '"Technically TCS is trading significantly above its anchor '
#                   'VWAP support mark of Rs 3,900 on its daily time frame '
#                   'chart. With the stock making higher highs and remaining '
#                   'well above its immediate support level, it appears poised '
#                   'to reach the Rs 4,030 and Rs 4,050 levels. The RSI (14) '
#                   'around 51 indicates potential momentum in the upcoming '
#                   'sessions. We advise traders to maintain a strict stop loss '
#                   'at Rs 3,875, aiming for potential targets of Rs 4,030 and '
#                   'Rs 4,050.”',
#   'author': 'Amit Mudgill',
#   'date_modified': '2024-07-11T17:30:01+05:30',
#   'date_published': '2024-07-11T17:26:53+05:30',
#   'description': 'TCS Q1 earnings: Large deals made in the last year seem to '
#                  'be getting converted into revenue along with the ramp-up of '
#                  'the BSNL deal. The lowering attrition and the net headcount '
#                  'addition is a major positive, analysts said.',
#   'scrapy_parsed_at': '2024-09-13T11:59:38.574481',
#   'scrapy_scraped_at': 'Fri, 13 Sep 2024 11:58:48 GMT',
#   'title': "'Upward revision in EPS estimates': What analysts say on TCS Q1 "
#            'results, stock trading strategy',
#   'url': 'https://www.businesstoday.in/markets/stocks/story/upward-revision-in-eps-estimates-what-analysts-say-on-tcs-q1-results-stock-trading-strategy-436794-2024-07-11'}]
#
# # Requests  -----------------------------------------------------------------
# []
